# %% [markdown]
# Main Python code to perform the simulation and display results

# %%
import numpy as np
from matplotlib import pyplot as plt, colors as mcolors
from scipy.integrate import solve_ivp
from scipy.constants import G, au
from sklearn.preprocessing import MinMaxScaler

import barneshut

# %% [markdown]
# Initial parameters:

# %%
massfactor = 10**24 # [kg]
scalefactor = 1000  # [au]
velocityfactor = 100  # []
accuracy = 0.001

# %% [markdown]
# Generate random body system:

# %%
count = 100

# %%
def massGen():
    for _ in range(count):
        yield abs(np.random.randn())*massfactor

def positionGen():
    for _ in range(count):
        yield np.random.randn(2)*scalefactor*au

def velocityGen():
    for _ in range(count):
        yield np.random.randn(2)*velocityfactor

# %%
bodies = zip(masses := np.array([[_ for _ in massGen()]]), positions := np.array([_ for _ in positionGen()]))

# %%
masses
# Out:
# array([[5.50265235e+23, 1.67643565e+24, 9.84757512e+23, 1.56125533e+24,
#         1.60190238e+24, 4.88957205e+23, 2.97086868e+23, 8.45145432e+23,
#         1.45495514e+24, 4.96352296e+22, 3.18568468e+23, 1.13106557e+24,
#         7.79744885e+23, 1.96857495e+24, 3.65801379e+22, 5.89705725e+23,
#         1.01105853e+24, 5.76590111e+23, 2.04572247e+24, 6.23296974e+23,
#         3.94883585e+22, 4.10229301e+23, 1.27383417e+24, 3.65608816e+23,
#         8.88233030e+23, 1.60232726e+24, 9.27577540e+23, 7.92948842e+23,
#         6.85794593e+23, 1.33774311e+24, 1.18039446e+24, 3.92135849e+23,
#         7.86794074e+23, 6.89028721e+23, 1.64186549e+24, 1.34554184e+24,
#         1.96497781e+24, 6.93183878e+23, 6.37836820e+23, 3.97347065e+22,
#         2.26765863e+22, 1.12365063e+24, 6.08815973e+23, 9.32619924e+23,
#         6.33236600e+23, 2.96241953e+24, 7.88734035e+23, 2.35264145e+23,
#         2.17085447e+23, 1.78760881e+24, 5.49392587e+23, 9.50080215e+23,
#         7.70473224e+23, 1.06649978e+23, 2.11587059e+23, 5.64647105e+23,
#         5.64215483e+23, 1.15375226e+24, 4.54428795e+22, 1.62866798e+24,
#         5.24304318e+23, 5.19461269e+23, 8.68937558e+23, 1.14385378e+24,
#         1.97910275e+24, 8.63072718e+23, 1.41642409e+24, 2.90878496e+23,
#         3.22114600e+23, 6.78430418e+23, 3.59044922e+23, 1.01086679e+24,
#         5.33351798e+23, 1.62906295e+24, 2.82972561e+23, 2.05968863e+23,
#         2.90083143e+23, 4.22954621e+23, 1.08260048e+23, 6.19607693e+23,
#         1.98299909e+24, 1.84221079e+24, 5.71373964e+23, 5.08230544e+23,
#         8.22190075e+23, 7.77378934e+23, 6.19000854e+23, 3.80690968e+23,
#         1.01995667e+24, 8.56037439e+23, 1.34935683e+24, 9.84641000e+22,
#         5.78195686e+22, 1.45589184e+24, 6.96495693e+23, 1.33933978e+24,
#         7.75216594e+23, 6.58014422e+23, 2.50071192e+23, 2.42671439e+23]])

# %%
velocities = np.array([_ for _ in velocityGen()])

# %% [markdown]
# Show data:

# %%
plt.title('Mass distribution')
plt.plot(masses.flatten())

# %%
mass_scaler = MinMaxScaler()
cmap = mass_scaler.fit_transform(masses.reshape(-1, 1))
c = mcolors.ColorConverter().to_rgb

plt.title('Bodies distribution')
plt.scatter(positions[:, 0], positions[:, 1], c=cmap)
plt.colorbar()

# %%
plt.title('Velocities')
plt.quiver(positions[:,0], positions[:,1], velocities[:,0], velocities[:,1])

# %% [markdown]
# Compute forces using C++ function:

# %%
state = np.concatenate((masses.T, positions), axis=1)
state.shape
# Out:
# (100, 3)

# %%
radius = max(abs(positions.flatten())) * 1.1  # Emergency reserve
radius
# Out:
# 548078685348499.25

# %%
result = np.array(barneshut.getForces(state, count, radius, accuracy)) * G
# Out:
# array([[-6.89189480e+10, -2.56451155e+09],
#        [ 1.75015743e+11,  7.34821866e+10],
#        [ 2.18659940e+11,  4.09503682e+10],
#        [-6.61992792e+10, -3.12759128e+09],
#        [ 1.88289645e+11,  6.45922168e+10],
#        [ 7.19095018e+10, -6.14595225e+10],
#        [ 3.53790719e+10, -1.85275583e+10],
#        [ 2.94876870e+10,  1.02382363e+09],
#        [-6.37238551e+11, -1.90496475e+11],
#        [ 2.31470310e+09,  6.16851680e+08],
#        [ 3.40277932e+10, -5.17153679e+10],
#        [ 1.02523192e+11,  1.15704086e+11],
#        [ 2.04869116e+11, -1.38197150e+11],
#        [-1.17308694e+11, -2.63944433e+10],
#        [ 1.16814827e+09, -8.67083236e+08],
#        [-1.26833190e+10, -5.55203238e+10],
#        [ 2.82849967e+11, -2.89428809e+11],
#        [-3.70779271e+10,  1.31303129e+10],
#        [-2.34094093e+11,  2.63833623e+11],
#        [ 4.90384382e+10,  7.05618470e+10],
#        [ 1.29803105e+09, -6.21786286e+09],
#        [ 6.25106362e+10,  4.78030657e+10],
#        [ 9.24498051e+10, -1.27971924e+11],
#        [-1.94122670e+10, -5.82818940e+10],
#        [-1.96183176e+11,  6.19404221e+10],
#        [ 6.45363756e+10, -7.99950812e+10],
#        [ 1.49872439e+11, -3.09239300e+11],
#        [ 8.80479219e+10,  9.17879764e+11],
#        [-3.01359417e+10, -2.50898308e+10],
#        [ 5.66077011e+10,  2.34222707e+08],
#        [-5.83082073e+10,  1.10318586e+11],
#        [ 1.66499645e+09,  3.07754999e+10],
#        [ 8.07380161e+10,  7.50994624e+10],
#        [ 5.01786804e+10, -6.69307538e+10],
#        [ 8.80841449e+10,  1.44739904e+11],
#        [ 6.69932170e+10, -1.74726819e+11],
#        [ 7.88430528e+09, -1.53495016e+11],
#        [ 8.57313848e+09, -1.51212057e+10],
#        [-3.85230692e+10, -7.78256453e+10],
#        [-1.46426591e+09,  8.21039936e+08],
#        [-8.18838859e+09,  2.68227553e+09],
#        [-2.73875602e+11, -1.00718287e+11],
#        [ 5.25868076e+11, -2.74322513e+10],
#        [ 3.22880287e+10,  7.29649701e+08],
#        [-1.83507301e+11, -8.95842719e+11],
#        [ 6.87526522e+11,  2.15451338e+11],
#        [ 3.77064372e+10,  8.01027165e+10],
#        [ 7.87913965e+09, -6.95450036e+09],
#        [-4.77878537e+09, -8.52345884e+09],
#        [-9.26342190e+10, -1.19327813e+11],
#        [ 3.69475696e+10, -2.03590728e+10],
#        [ 1.32095557e+11,  6.66179757e+09],
#        [ 4.65471643e+10,  3.17407675e+10],
#        [-4.38538909e+10,  2.53433928e+10],
#        [-9.91378493e+07,  7.13923274e+09],
#        [ 2.65605942e+10, -4.37393285e+09],
#        [ 4.72160125e+10, -3.04749748e+10],
#        [ 4.01101334e+10,  1.79476811e+11],
#        [ 5.07968170e+10,  4.23542158e+10],
#        [ 8.21210512e+09,  2.99766812e+10],
#        [-4.48852808e+10, -8.71480784e+09],
#        [ 1.51071268e+10, -2.05507135e+10],
#        [-1.88915425e+11,  3.80269949e+11],
#        [ 2.25438688e+10, -3.06742392e+10],
#        [-3.31774367e+11,  3.97833141e+11],
#        [ 3.34220808e+11, -6.00515001e+11],
#        [-1.20744920e+11, -9.26840297e+11],
#        [-7.74568701e+09, -1.76199516e+10],
#        [-9.55100018e+09,  4.15027116e+10],
#        [ 6.10078327e+10, -8.82890182e+10],
#        [ 2.94791268e+10,  2.40472702e+10],
#        [-4.86740750e+10, -1.59762570e+10],
#        [-1.66727757e+10, -1.81798934e+10],
#        [-1.68507382e+11,  1.48064467e+11],
#        [ 2.73374246e+10,  2.03373784e+10],
#        [ 5.20922620e+09, -1.11505269e+10],
#        [ 1.65961451e+10,  1.25838966e+11],
#        [ 3.39617367e+10, -6.83212056e+10],
#        [-6.50608227e+09,  3.19324328e+09],
#        [ 6.23358593e+10, -8.09916496e+10],
#        [ 1.09492307e+11, -1.32261444e+11],
#        [ 3.05526498e+11, -1.15789933e+11],
#        [-6.15888555e+11,  1.74120962e+11],
#        [ 3.96469929e+10,  8.66606786e+09],
#        [ 1.07180482e+11, -2.77758008e+08],
#        [-4.72295684e+10,  4.86768254e+09],
#        [ 4.72764515e+10, -9.17855634e+10],
#        [-4.80612761e+11,  2.72160605e+11],
#        [ 1.88050786e+10, -2.75191220e+11],
#        [-6.03973422e+10,  7.60777887e+10],
#        [-3.11259926e+10, -9.86055842e+10],
#        [-2.07086063e+09,  1.29836969e+08],
#        [-1.40050428e+11,  3.34597765e+10],
#        [ 2.11745462e+10, -1.09084177e+10],
#        [-1.18470336e+11,  7.85706319e+11],
#        [-1.13492284e+11,  4.58521555e+10],
#        [-1.16835121e+10,  1.95294121e+10],
#        [-4.69852470e+11,  4.77039954e+11],
#        [-1.95724234e+10,  8.36116762e+09],
#        [ 2.72805695e+10,  5.76196420e+10]])
# Computation starting..
# Conversion..
# Tree construction..
# Force computation..
# Conversion..
# Done!
# Cleaning up memory.. Memory stack: 0

# %%
result.shape
# Out:
# (100, 2)

# %%
fig, ax = plt.subplots()
ax.quiver(positions[:,0], positions[:,1], result[:,0], result[:,1])
ax.set_title('Forces')
ax.axis('equal')

plt.show()

# %%
positions[0].shape
# Out:
# (2,)

# %%
state[0].shape
# Out:
# (3,)

# %%
state.shape
# Out:
# (100, 3)
