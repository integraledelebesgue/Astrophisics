# %% [markdown]
# Main Python code to perform the simulation and display results

# %%
import numpy as np
from matplotlib import pyplot as plt, colors as mcolors
from scipy.integrate import solve_ivp
from scipy.constants import G, au
from sklearn.preprocessing import MinMaxScaler

from ctypes import c_void_p, c_double, c_int, CDLL
from numpy.ctypeslib import ndpointer

#import cffi

# %%
massfactor = 10**24 # [kg]
scalefactor = 100  # [au]
velocityfactor = 100  # []
accuracy = 0.3

# %% [markdown]
# Generate random body system:

# %%
count = 100

# %%
def massGen():
    for _ in range(count):
        yield abs(np.random.randn())*massfactor

def positionGen():
    for _ in range(count):
        yield np.random.randn(2)*scalefactor*au

def velocityGen():
    for _ in range(count):
        yield np.random.randn(2)*velocityfactor

# %%
bodies = zip(masses := np.array([[_ for _ in massGen()]]), positions := np.array([_ for _ in positionGen()]))

# %%
velocities = np.array([_ for _ in velocityGen()])

# %% [markdown]
# Show data:

# %%
plt.title('Mass distribution')
plt.plot(masses.flatten())

# %%
mass_scaler = MinMaxScaler()
cmap = mass_scaler.fit_transform(masses.reshape(-2, 2))
c = mcolors.ColorConverter().to_rgb

plt.title('Bodies distribution')
plt.scatter(positions[:, 0], positions[:, 1], c=cmap)
plt.colorbar()

# %%
plt.title('Velocities')
plt.quiver(positions[:,0], positions[:,1], velocities[:,0], velocities[:,1])

# %% [markdown]
# Construct Python function from C shared library:

# %%
lib = CDLL("./Elements/barneshut.so", mode = RTLD_GLOBAL)
#computeForces = lib.perform(ndpointer(dtype=c_double, shape=(count,2))(body_list),  )
lib.perform.argtypes = [ndpointer(dtype=c_double, shape=(count, 3)), c_int, c_double, c_double]
computeForces.restype = ndpointer(dtype=c_double,
                          shape=(count,2))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_23150/3798307045.py in <module>
# ----> 1 lib = CDLL("./Elements/barneshut.so", mode = RTLD_GLOBAL)
#       2 #computeForces = lib.perform(ndpointer(dtype=c_double, shape=(count,2))(body_list),  )
#       3 lib.perform.argtypes = [ndpointer(dtype=c_double, shape=(count, 3)), c_int, c_double, c_double]
#       4 computeForces.restype = ndpointer(dtype=c_double,
#       5                           shape=(count,2))
#
# NameError: name 'RTLD_GLOBAL' is not defined

# %% [markdown]
# Compute forces using C function:

# %%
state = np.concatenate((masses.T, positions), axis=1)
state
# Out:
# array([[ 2.07412654e+24,  3.17276574e+12,  4.73338074e+11],
#        [ 2.59313669e+23, -6.81558482e+11,  1.27942346e+13],
#        [ 3.04926100e+23,  1.65827113e+12, -2.42668489e+13],
#        [ 1.71597430e+23,  2.18412261e+13,  7.78682314e+12],
#        [ 4.19752387e+23,  2.19855484e+13, -4.84035581e+12],
#        [ 1.50353620e+23, -3.18213846e+12, -1.70322773e+12],
#        [ 1.32099627e+23,  2.19596322e+13,  1.05423172e+13],
#        [ 2.25203496e+24,  3.20554377e+12,  1.51619694e+13],
#        [ 5.16011955e+23,  3.08391832e+13, -6.05132102e+12],
#        [ 1.63250725e+24, -1.58545664e+13, -5.80270442e+12],
#        [ 6.11140008e+23,  2.33849678e+13,  6.37325637e+12],
#        [ 5.03030106e+23,  1.28064688e+13, -2.05631405e+12],
#        [ 8.05076632e+23, -2.93671556e+12, -1.46110984e+12],
#        [ 9.05897882e+23,  6.79342332e+12,  1.83174130e+13],
#        [ 1.18773194e+23, -2.28122316e+11,  1.29232681e+13],
#        [ 2.25302609e+24, -1.95740510e+13,  1.89909908e+13],
#        [ 1.09432696e+24, -2.25587462e+13, -6.93263804e+12],
#        [ 3.58907966e+23, -1.11580919e+13,  1.76715207e+13],
#        [ 1.22977604e+24, -7.55287116e+12, -2.22537533e+12],
#        [ 7.47951591e+23, -1.85774737e+12, -4.61966032e+12],
#        [ 6.75618233e+23, -2.35430628e+13, -7.44552547e+12]])

# %%
radius = max(abs(positions.flatten()))
radius
# Out:
# 53010270292688.836

# %%
#forces = computeForces(c_void_p(state.ctypes.data),c_int(count),c_double(accuracy), c_double(radius))

# %%
np.ctypeslib.ndpointer?
# Out:
# Signature: np.ctypeslib.ndpointer(dtype=None, ndim=None, shape=None, flags=None)
# Docstring:
# Array-checking restype/argtypes.
#
# An ndpointer instance is used to describe an ndarray in restypes
# and argtypes specifications.  This approach is more flexible than
# using, for example, ``POINTER(c_double)``, since several restrictions
# can be specified, which are verified upon calling the ctypes function.
# These include data type, number of dimensions, shape and flags.  If a
# given array does not satisfy the specified restrictions,
# a ``TypeError`` is raised.
#
# Parameters
# ----------
# dtype : data-type, optional
#     Array data-type.
# ndim : int, optional
#     Number of array dimensions.
# shape : tuple of ints, optional
#     Array shape.
# flags : str or tuple of str
#     Array flags; may be one or more of:
#
#       - C_CONTIGUOUS / C / CONTIGUOUS
#       - F_CONTIGUOUS / F / FORTRAN
#       - OWNDATA / O
#       - WRITEABLE / W
#       - ALIGNED / A
#       - WRITEBACKIFCOPY / X
#       - UPDATEIFCOPY / U
#
# Returns
# -------
# klass : ndpointer type object
#     A type object, which is an ``_ndtpr`` instance containing
#     dtype, ndim, shape and flags information.
#
# Raises
# ------
# TypeError
#     If a given array does not satisfy the specified restrictions.
#
# Examples
# --------
# >>> clib.somefunc.argtypes = [np.ctypeslib.ndpointer(dtype=np.float64,
# ...                                                  ndim=1,
# ...                                                  flags='C_CONTIGUOUS')]
# ... #doctest: +SKIP
# >>> clib.somefunc(np.array([1, 2, 3], dtype=np.float64))
# ... #doctest: +SKIP
# File:      ~/anaconda3/lib/python3.9/site-packages/numpy/ctypeslib.py
# Type:      function
